# %% [markdown]
# ## Tools Preparation
# Scrapping is basically one of the way to retrieve the data and this process is very important to know as a data scientist since sometimes we cannot get data easily as we querying the data from the database or download Kaggle. We're going to scrape Gramedia.com in this lesson using Beautifulsoup. Before we're going further, please install beautifulsoup.
#
# To install beautifulsoup, you may run one of the following commands on Anaconda Prompt (Windows) or Terminal (Linux/Mac/VSCode):
#
# ```
# pip install bs4
# ```
#
# and also you need to install requests to acces a web address by running:
#
# ```
# pip install requests
# ```

# %% [markdown]
# ## Basic Web Component
#
# The website that you are scraping in this lesson contains several components. Those are:
# - HTML — the main content of the page.
# - CSS — used to add styling to make the page look nicer.
# - JS — Javascript files add interactivity to web pages.
# - Images — image formats, such as JPG and PNG, allow web pages to show pictures.
#
# There’s a lot that happens behind the scenes to render a page nicely, but we don’t need to worry about most of it when we’re web scraping. When we perform web scraping, we’re interested in the main content of the web page, so we look primarily at the HTML. Hence, you need to know some HTML structure to ease your scraping works. But don't worry, you don't need to dive in deeply into it.
#
# ### HTML Structure
#
# HyperText Markup Language (HTML) is the language that web pages are created in. HTML isn’t a programming language, like Python, though. It’s a markup language that tells a browser how to display content.
#
# HTML has many functions that are similar to what you might find in a word processor like Microsoft Word — it can make text bold, create paragraphs, and so on.
#
# Below an example of HTML structure:
#
# ```html
# <HTML>
#     <HEAD>
#         <TITLE>My cool title</TITLE>
#     </HEAD>
#     <BODY>
#         <H1>This is a Header</H1>
#         <ul id="list" class="coolList">
#             <li>item 1</li>
#             <li>item 2</li>
#             <li>item 3</li>
#         </ul>
#     </BODY>
# </HTML>
# ```
#
# - The red items are called as tag or element. Usually, tag follows "<".
# - HTML, HEAD, and BODY are the main elements and the rests are the content. For your attention, we will focus on the contents.
# - The orange items are attribut that give information about the tag.
# - The blue texts are the attribute value.

# %% [markdown]
# ## Accessing the Web
#
# Now, we will access https://www.gramedia.com/categories/buku for this lesson. Before we go further, we need to understand how to access the url in Python. To do it, we use requests library.

# %%
import requests
page = requests.get("https://www.gramedia.com/categories/buku")
respons=requests.get('https://news.ycombinator.com/')
page
# Out:
# <Response [200]>

# %% [markdown]
# If you see the output is <Response [200]>, then you are success to access the url. "200" refers to HTTP status codes. You can read https://id.wikipedia.org/wiki/Daftar_kode_status_HTTP for further explaination.
#
# Now, you can check the HTML content of the page in Python. However, you can also check it on your browser by right click and choose Inspect element to ease your understanding od the web structure.

# %% [markdown]
# Above is the HTML structure that Python successfully access. We need to parsing the structure using Beautifulsoup to make it clear and accessible to scrape.

# %%
# !pip install selenium

# %%
from selenium import webdriver

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
driver = webdriver.Chrome('Web Scraping/chromedriver')

url="https://web.whatsapp.com/"
driver.get(url)
html = driver.page_source
soup = BeautifulSoup(html, "html.parser")
# print(soup.prettify()[:700])
# Out:
# C:\Users\wahyu\AppData\Local\Temp\ipykernel_6096\1524012141.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('Web Scraping/chromedriver')

# %%
driver.close()

# %%
soup.find_all()
# Out:
# [<html class="js serviceworker adownload cssanimations csstransitions webp exiforientation webp-alpha webp-animation webp-lossless" dir="LTR" lang="en" loc="en"><head><meta charset="utf-8"/><meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/><title>WhatsApp</title><meta content="width=device-width" name="viewport"/><meta content="notranslate" name="google"/><meta content="telephone=no" name="format-detection"/><meta content="Quickly send and receive WhatsApp messages right from your computer." name="description"/><meta content="Quickly send and receive WhatsApp messages right from your computer." name="og:description"/><meta content="https://web.whatsapp.com/" name="og:url"/><meta content="WhatsApp Web" name="og:title"/><meta content="https://static.facebook.com/images/whatsapp/www/whatsapp-promo.png" name="og:image"/><link href="/apple-touch-icon.png" rel="apple-touch-icon" sizes="194x194" type="image/png"/><style>#initial_startup{--startup-background:#f0f2f5;--startup-background-rgb:240,242,245;--startup-icon:#bbc5cb;--secondary-lighter:#8696a0;--primary-title:#41525d;--progress-primary:#00c298;--progress-background:#e9edef}.dark #initial_startup{--startup-background:#111b21;--startup-background-rgb:17,27,33;--startup-icon:#676f73;--primary-title:rgba(233, 237, 239, 0.88);--secondary-lighter:#667781;--progress-primary:#0b846d;--progress-background:#233138}#app,body,html{width:100%;height:100%;padding:0;margin:0;overflow:hidden}#app{position:absolute;top:0;left:0}#initial_startup{position:fixed;top:0;left:0;display:flex;flex-direction:column;align-items:center;justify-content:center;width:100%;height:100%;user-select:none;background-color:var(--startup-background)}#initial_startup .graphic{margin-top:-40px;color:var(--startup-icon)}#initial_startup .graphic .resume-logo{transform:translateX(calc(50% - 52px / 2))}#initial_startup .graphic::after{position:relative;top:-100%;left:calc(50% - 72px * 2 - 72px / 2);display:block;width:calc(72px * 3);height:100%;content:'';background:linear-gradient(to right,rgba(var(--startup-background-rgb),.5) 0,rgba(var(--startup-background-rgb),.5) 33.33%,rgba(var(--startup-background-rgb),0) 44.1%,rgba(var(--startup-background-rgb),0) 55.8%,rgba(var(--startup-background-rgb),.5) 66.66%,rgba(var(--startup-background-rgb),.5) 100%);opacity:1;animation:shimmer 1.5s linear .6s infinite}html[dir=rtl] #initial_startup .graphic::after{animation-direction:reverse}@keyframes shimmer{from{left:calc(50% - 72px * 2 - 72px / 2)}to{left:calc(50% - 72px / 2)}}#initial_startup .progress{position:relative;width:420px;height:3px;margin-top:40px}#initial_startup .progress progress{vertical-align:top}#initial_startup .main{margin-top:40px;font-size:17px;color:var(--primary-title)}#initial_startup .secondary{margin-top:12px;font-size:14px;color:var(--secondary-lighter)}#initial_startup .secondary span{display:inline-block;margin-bottom:2px;vertical-align:middle}progress{-webkit-appearance:none;appearance:none;width:100%;height:3px;margin:0;color:var(--progress-primary);background-color:var(--progress-background);border:none}progress[value]::-webkit-progress-bar{background-color:var(--progress-background)}progress[value]::-moz-progress-bar,progress[value]::-webkit-progress-value{background-color:var(--progress-primary);transition:width .45s ease}</style><link href="/stylex-46bbe207e10ab975fa34262d5fd42ebf.css" rel="stylesheet"/><link href="/bootstrap_qr-803fb3b72281c6db05ae.css" rel="stylesheet"/><link href="/bootstrap_main.c62a8354f6f1e36da765.css" rel="stylesheet" type="text/css"/><style id="asset-style" type="text/css"></style><link href="/img/favicon_c5088e888c97ad440a61d247596f88e5.png" id="favicon" rel="shortcut icon" src="/img/favicon_c5088e888c97ad440a61d247596f88e5.png" type="image/png"/></head><body class="web dark"><script data-binary-transparency-hash-key="inline-js-4b79b6dc91a7ee33373b115991c3eb287ed710cfb6708421b4cab682eddbfcbd">try{var systemThemeDark,theme=window.localStorage.getItem(""),s ...
#  (self.webpackChunkwhatsapp_web_client=self.webpackChunkwhatsapp_web_client||[]).push([[5617],{595318:e=>{e.exports=function(e){return e&&e.__esModule?e:{default:e}},e.exports.default=e.exports,e.exports.__esModule=!0},145095:(e,t)=>{"use strict";Object.defineProperty(t,"__esModule",{value:!0}),t.default=function(e){let t=arguments.length>1&&void 0!==arguments[1]?arguments[1]:"?";if(null==e)throw new Error("Unexpected null or undefined: "+t);return e}},520289:(e,t)=>{"use strict";Object.defineProperty(t,"__esModule",{value:!0}),t.UPLOAD_TO_CLB=t.TICKET_URL=t.LOG_SIZE=t.CLB_URL=t.CLB_TOKEN=t.CLB_CHECK_URL=void 0,t.CLB_CHECK_URL="https://crashlogs.whatsapp.net/wa_fls_upload_check",t.CLB_TOKEN="1063127757113399|745146ffa34413f9dbb5469f5370b7af",t.CLB_URL="https://crashlogs.whatsapp.net/wa_clb_data",t.TICKET_URL="https://web.whatsapp.com/web-contact-us";let n=0;n=1,t.UPLOAD_TO_CLB=1,t.LOG_SIZE=4999},257977:(e,t)=>{"use strict";Object.defineProperty(t,"__esModule",{value:!0}),t.getDistribution=function(){let e="unknown";return e="prod","web_prod"},t.getLogUserAgent=function(e){let t,{appVersion:n,browser:r,device:o}=e;return t="Web/"+r,`WhatsApp/${n} ${t} Device/${o}`}},646722:(e,t,n)=>{"use strict";var r=n(595318),o=r(n(145095)),a=n(520289),s=n(257977),c=r(n(904285)),l=n(104617);function i(e){!function(e,t){const n=window.navigator.userAgent;if(n===p&&e.includes("getElementsByTagName"))return;const r=new FormData,i=new Blob([e],{type:"text/plain"});r.append("from_jid",function(){if(f)return f;try{f=JSON.parse((0,o.default)(c.default,"localStorage").getItem(d)),f&&(f=f.replace("-",""))}catch(e){}if(!f){f="unknown"+Math.floor(1e10*Math.random());const e=f;try{(0,o.default)(c.default,"localStorage").setItem(d,JSON.stringify(e))}catch(e){}}return(0,o.default)(f,"id")}()),r.append("agent",(0,s.getLogUserAgent)((0,l.parseUASimple)(n,"2.2224.8"))),r.append("file",i,"logs.txt"),r.append("tags","load");const u=new XMLHttpRequest,_=a.CLB_URL+"?access_token="+encodeURIComponent(a.CLB_TOKEN);u.open("POST",_,!0),u.send(r)}(e)}function u(e){let{error:t,reason:n,stack:r}=e;const o=(new Date).toISOString();return`${o}: error: ${t}\n${o}: reason for logs: ${n}\n${o}: userAgent: ${window.navigator.userAgent}\n${r}`}null==window.onerror&&(window.onerror=function(e,t,n){const r=t.split("?")[0];return"Uncaught SyntaxError: Unexpected token '<'"===e?(function(e){i(u({error:"failed to load a js or css bundle",reason:`failed to load [${e.split("/")[3].replace(/^\//,"")}]`,stack:""}))}(r),!0):(i(u({error:e,reason:`Error at [${r}:${n}]`,stack:""})),!1)});const d="WAUnknownID",p="Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.113 Safari/537.36";let f},104617:(e,t)=>{"use strict";function n(e){return e.includes("windows")?"Windows":e.includes("mac")?"Mac OS":e.includes("linux")?"Linux":"Unparsed"}Object.defineProperty(t,"__esModule",{value:!0}),t.parseUASimple=function(e,t){const r=e.toLowerCase();return{browser:s(r),device:n(r),appVersion:t}};const r=/(chrome|firefox)\/([\w\.]+)/i,o=/(edge|opr)\/([\w\.]+)/i,a={chrome:"Chrome",edge:"Edge",opr:"Opera",firefox:"Firefox"};function s(e){const t=e.match(o)||e.match(r);return null==t?"Unparsed":`${a[t[1]]} ${t[2]}`}},904285:(e,t)=>{"use strict";let n;Object.defineProperty(t,"__esModule",{value:!0}),t.default=void 0;try{n=window.localStorage}catch(e){}var r=n;t.default=r}},e=>{"use strict";e(e.s=646722)}])</script><script defer="defer" src="/vendor1~bootstrap_qr.479b880772705c9f1664.js"></script><script defer="defer" src="/bootstrap_qr.2c01e0e4abde696b6ff5.js"></script><script data-binary-transparency-hash-key="inline-js-9c8cd3d0f4d5af8c7f5cd1c45208edd308bfe472e353a50e4cbacbf6cb58627c">(i => {const l = document.getElementById(i); l &&fetch(l.href).then(b => b.text()).then(code => {const script = document.createElement('script');script.id = 'binary-transparency-manifest';script.type = 'application/json';script.innerHTML = code;document.body.append(script);});} ...
#    "version": "2.2224.8",
#    "hash_function": "SHA256",
#    "root": "0x40a85dec744b8063c38b62968e2c994c51d1d685658d5792603fe89e9502320d",
#    "leaves": [
#      "0x001ccf8cfa2738293a88c9310e932aa1d309ff06fb63d82fd949ec0cbb5a9d6f",
#      "0x00c07573ac9b9b88feb2d38f442d28e77780f9c1fb6d43d6bc8abfb4ce635819",
#      "0x01ffb8bcc8896cdde4ed603cb561521dbaaa4a44493e57c8a9b40607b59146c2",
#      "0x0221a287b686dcbbccb81e234e387daa6a8586ca1f0802ed0a4da7401fd4fed9",
#      "0x041f0886338348bc18bd15bdea0cc4147b91f40980074c70863f71e164bfa75f",
#      "0x0436e2cb1e40471537214c2608f05baa45b906e47b41c5db32b2c44f1206e8bf",
#      "0x04aa37ef95a1e296395bc409312f638a969af8f1df315583320989107172a0e6",
#      "0x067596edefa819f53a771d6f798f9270250f67d7da4f74398ae4ed81e66d5754",
#      "0x07eedfe1774879aef53d8781379fbb6c6804533445cb9b781ca7561ef9e1c080",
#      "0x0873826c294fb3a9c943f0101e9aa53bb8e66b542f9c726868d8af31d2ae4407",
#      "0x093f6844a46c6ddf0696b62637df6df11e507e942cb202b2edce84c19dfed6c3",
#      "0x0a25bc23478c3fd77a473636cc4f818211da694988268537c67374846ef37ce2",
#      "0x0bd4a164d633663750ece14aeddd1988b4e3fd6b11bc8297aa27e44417929845",
#      "0x0c04ec58c1e1b133085f89aaaa05d7176431a9467b36cea39b4a549b7c2d5107",
#      "0x0c4fdce4419591264de09a615e071e6a9275b6ccdcbdfa06322fb8d5ca0fc568",
#      "0x153e10191162e66b01c80f385e207e7214cc52286b991bcdb3b03d870af02b3d",
href="/apple-touch-icon.png" rel="apple-touch-icon" sizes="194x194" type="image/png"/><style>#initial_startup{--startup-background:#f0f2f5;--startup-background-rgb:240,242,245;--startup-icon:#bbc5cb;--secondary-lighter:#8696a0;--primary-title:#41525d;--progress-primary:#00c298;--progress-background:#e9edef}.dark #initial_startup{--startup-background:#111b21;--startup-background-rgb:17,27,33;--startup-icon:#676f73;--primary-title:rgba(233, 237, 239, 0.88);--secondary-lighter:#667781;--progress-primary:#0b846d;--progress-background:#233138}#app,body,html{width:100%;height:100%;padding:0;margin:0;overflow:hidden}#app{position:absolute;top:0;left:0}#initial_startup{position:fixed;top:0;left:0;display:flex;flex-direction:column;align-items:center;justify-content:center;width:100%;height:100%;user-select:none;background-color:var(--startup-background)}#initial_startup .graphic{margin-top:-40px;color:var(--startup-icon)}#initial_startup .graphic .resume-logo{transform:translateX(calc(50% - 52px / 2))}#initial_startup .graphic::after{position:relative;top:-100%;left:calc(50% - 72px * 2 - 72px / 2);display:block;width:calc(72px * 3);height:100%;content:'';background:linear-gradient(to right,rgba(var(--startup-background-rgb),.5) 0,rgba(var(--startup-background-rgb),.5) 33.33%,rgba(var(--startup-background-rgb),0) 44.1%,rgba(var(--startup-background-rgb),0) 55.8%,rgba(var(--startup-background-rgb),.5) 66.66%,rgba(var(--startup-background-rgb),.5) 100%);opacity:1;animation:shimmer 1.5s linear .6s infinite}html[dir=rtl] #initial_startup .graphic::after{animation-direction:reverse}@keyframes shimmer{from{left:calc(50% - 72px * 2 - 72px / 2)}to{left:calc(50% - 72px / 2)}}#initial_startup .progress{position:relative;width:420px;height:3px;margin-top:40px}#initial_startup .progress progress{vertical-align:top}#initial_startup .main{margin-top:40px;font-size:17px;color:var(--primary-title)}#initial_startup .secondary{margin-top:12px;font-size:14px;color:var(--secondary-lighter)}#initial_startup .secondary span{display:inline-block;margin-bottom:2px;vertical-align:middle}progress{-webkit-appearance:none;appearance:none;width:100%;height:3px;margin:0;color:var(--progress-primary);background-color:var(--progress-background);border:none}progress[value]::-webkit-progress-bar{background-color:var(--progress-background)}progress[value]::-moz-progress-bar,progress[value]::-webkit-progress-value{background-color:var(--progress-primary);transition:width .45s ease}</style><link href="/stylex-46bbe207e10ab975fa34262d5fd42ebf.css" rel="stylesheet"/><link href="/bootstrap_qr-803fb3b72281c6db05ae.css" rel="stylesheet"/><link href="/bootstrap_main.c62a8354f6f1e36da765.css" rel="stylesheet" type="text/css"/><style id="asset-style" type="text/css"></style><link href="/img/favicon_c5088e888c97ad440a61d247596f88e5.png" id="favicon" rel="shortcut icon" src="/img/favicon_c5088e888c97ad440a61d247596f88e5.png" type="image/png"/></head>,
#  <meta charset="utf-8"/>,
#  <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>,
#  <title>WhatsApp</title>,
#  <meta content="width=device-width" name="viewport"/>,
#  <meta content="notranslate" name="google"/>,
#  <meta content="telephone=no" name="format-detection"/>,
#  <meta content="Quickly send and receive WhatsApp messages right from your computer." name="description"/>,
#  <meta content="Quickly send and receive WhatsApp messages right from your computer." name="og:description"/>,
#  <meta content="https://web.whatsapp.com/" name="og:url"/>,
#  <meta content="WhatsApp Web" name="og:title"/>,
#  <meta content="https://static.facebook.com/images/whatsapp/www/whatsapp-promo.png" name="og:image"/>,
#  <link href="/apple-touch-icon.png" rel="apple-touch-icon" sizes="194x194" type="image/png"/>,
#  <style>#initial_startup{--startup-background:#f0f2f5;--startup-background-rgb:240,242,245;--startup-icon:#bbc5cb;--secondary-lighter:#8696a0;--primary-title:#41525d;--progress-primary:#00c298;--progress-background:#e9edef}.dark #initial_startup{--startup-background:#111b21;--startup-background-rgb:17,27,33;--startup-icon:#676f73;--primary-title:rgba(233, 237, 239, 0.88);--secondary-lighter:#667781;--progress-primary:#0b846d;--progress-background:#233138}#app,body,html{width:100%;height:100%;padding:0;margin:0;overflow:hidden}#app{position:absolute;top:0;left:0}#initial_startup{position:fixed;top:0;left:0;display:flex;flex-direction:column;align-items:center;justify-content:center;width:100%;height:100%;user-select:none;background-color:var(--startup-background)}#initial_startup .graphic{margin-top:-40px;color:var(--startup-icon)}#initial_startup .graphic .resume-logo{transform:translateX(calc(50% - 52px / 2))}#initial_startup .graphic::after{position:relative;top:-100%;left:calc(50% - 72px * 2 - 72px / 2);display:block;width:calc(72px * 3);height:100%;content:'';background:linear-gradient(to right,rgba(var(--startup-background-rgb),.5) 0,rgba(var(--startup-background-rgb),.5) 33.33%,rgba(var(--startup-background-rgb),0) 44.1%,rgba(var(--startup-background-rgb),0) 55.8%,rgba(var(--startup-background-rgb),.5) 66.66%,rgba(var(--startup-background-rgb),.5) 100%);opacity:1;animation:shimmer 1.5s linear .6s infinite}html[dir=rtl] #initial_startup .graphic::after{animation-direction:reverse}@keyframes shimmer{from{left:calc(50% - 72px * 2 - 72px / 2)}to{left:calc(50% - 72px / 2)}}#initial_startup .progress{position:relative;width:420px;height:3px;margin-top:40px}#initial_startup .progress progress{vertical-align:top}#initial_startup .main{margin-top:40px;font-size:17px;color:var(--primary-title)}#initial_startup .secondary{margin-top:12px;font-size:14px;color:var(--secondary-lighter)}#initial_startup .secondary span{display:inline-block;margin-bottom:2px;vertical-align:middle}progress{-webkit-appearance:none;appearance:none;width:100%;height:3px;margin:0;color:var(--progress-primary);background-color:var(--progress-background);border:none}progress[value]::-webkit-progress-bar{background-color:var(--progress-background)}progress[value]::-moz-progress-bar,progress[value]::-webkit-progress-value{background-color:var(--progress-primary);transition:width .45s ease}</style>,
#  <link href="/stylex-46bbe207e10ab975fa34262d5fd42ebf.css" rel="stylesheet"/>,
#  <link href="/bootstrap_qr-803fb3b72281c6db05ae.css" rel="stylesheet"/>,
#  <link href="/bootstrap_main.c62a8354f6f1e36da765.css" rel="stylesheet" type="text/css"/>,
#  <style id="asset-style" type="text/css"></style>,
#  <link href="/img/favicon_c5088e888c97ad440a61d247596f88e5.png" id="favicon" rel="shortcut icon" src="/img/favicon_c5088e888c97ad440a61d247596f88e5.png" type="image/png"/>,
#  <body class="web dark"><script data-binary-transparency-hash-key="inline-js-4b79b6dc91a7ee33373b115991c3eb287ed710cfb6708421b4cab682eddbfcbd">try{var systemThemeDark,theme=window.localStorage.getItem(""),systemThemeMode=window.localStorage.getItem("system-theme-mode");if(("true"===systemThemeMode||!theme)&&window.matchMedia){var systemTheme=window.matchMedia("(prefers-color-scheme: dark)");systemThemeDark=systemTheme&&systemTheme.matches}var darkTheme='"dark"'===theme||Boolean(systemThemeDark);darkTheme&&document.body.classList.add("dark")}catch(e){}</script><div id="app"><div class="_1ADa8 nMnIl app-wrapper-web font-fix os-win"><span></span><div class="landing-wrapper"><div class="landing-header"><span class="l7jjieqr fewfhwl7"><svg height="39" viewbox="0 0 39 39" width="39" xmlns="http://www.w3.org/2000/svg"><path d="M10.7 32.8l.6.3c2.5 1.5 5.3 2.2 8.1 2.2 8.8 0 16-7.2 16-16 0-4.2-1.7-8.3-4.7-11.3s-7-4.7-11.3-4.7c-8.8 0-16 7.2-15.9 16.1 0 3 .9 5.9 2.4 8.4l.4.6-1.6 5.9 6-1.5z" fill="#00E676"></path><path d="M32.4 6.4C29 2.9 24.3 1 19.5 1 9.3 1 1.1 9.3 1.2 19.4c0 3.2.9 6.3 2.4 9.1L1 38l9.7-2.5c2.7 1.5 5.7 2.2 8.7 2.2 10.1 0 18.3-8.3 18.3-18.4 0-4.9-1.9-9.5-5.3-12.9zM19.5 34.6c-2.7 0-5.4-.7-7.7-2.1l-.6-.3-5.8 1.5L6.9 28l-.4-.6c-4.4-7.1-2.3-16.5 4.9-20.9s16.5-2.3 20.9 4.9 2.3 16.5-4.9 20.9c-2.3 1.5-5.1 2.3-7.9 2.3zm8.8-11.1l-1.1-.5s-1.6-.7-2.6-1.2c-.1 0-.2-.1-.3-.1-.3 0-.5.1-.7.2 0 0-.1.1-1.5 1.7-.1.2-.3.3-.5.3h-.1c-.1 0-.3-.1-.4-.2l-.5-.2c-1.1-.5-2.1-1.1-2.9-1.9-.2-.2-.5-.4-.7-.6-.7-.7-1.4-1.5-1.9-2.4l-.1-.2c-.1-.1-.1-.2-.2-.4 0-.2 0-.4.1-.5 0 0 .4-.5.7-.8.2-.2.3-.5.5-.7.2-.3.3-.7.2-1-.1-.5-1.3-3.2-1.6-3.8-.2-.3-.4-.4-.7-.5h-1.1c-.2 0-.4.1-.6.1l-.1.1c-.2.1-.4.3-.6.4-.2.2-.3.4-.5.6-.7.9-1.1 2-1.1 3.1 0 .8.2 1.6.5 2.3l.1.3c.9 1.9 2.1 3.6 3.7 5.1l.4.4c.3.3.6.5.8.8 2.1 1.8 4.5 3.1 7.2 3.8.3.1.7.1 1 .2h1c.5 0 1.1-.2 1.5-.4.3-.2.5-.2.7-.4l.2-.2c.2-.2.4-.3.6-.5s.4-.4.5-.6c.2-.4.3-.9.4-1.4v-.7s-.1-.1-.3-.2z" fill="#FFF"></path></svg></span><div class="landing-headerTitle">Wh
#  (self.webpackChunkwhatsapp_web_client=self.webpackChunkwhatsapp_web_client||[]).push([[5617],{595318:e=>{e.exports=function(e){return e&&e.__esModule?e:{default:e}},e.exports.default=e.exports,e.exports.__esModule=!0},145095:(e,t)=>{"use strict";Object.defineProperty(t,"__esModule",{value:!0}),t.default=function(e){let t=arguments.length>1&&void 0!==arguments[1]?arguments[1]:"?";if(null==e)throw new Error("Unexpected null or undefined: "+t);return e}},520289:(e,t)=>{"use strict";Object.defineProperty(t,"__esModule",{value:!0}),t.UPLOAD_TO_CLB=t.TICKET_URL=t.LOG_SIZE=t.CLB_URL=t.CLB_TOKEN=t.CLB_CHECK_URL=void 0,t.CLB_CHECK_URL="https://crashlogs.whatsapp.net/wa_fls_upload_check",t.CLB_TOKEN="1063127757113399|745146ffa34413f9dbb5469f5370b7af",t.CLB_URL="https://crashlogs.whatsapp.net/wa_clb_data",t.TICKET_URL="https://web.whatsapp.com/web-contact-us";let n=0;n=1,t.UPLOAD_TO_CLB=1,t.LOG_SIZE=4999},257977:(e,t)=>{"use strict";Object.defineProperty(t,"__esModule",{value:!0}),t.getDistribution=function(){let e="unknown";return e="prod","web_prod"},t.getLogUserAgent=function(e){let t,{appVersion:n,browser:r,device:o}=e;return t="Web/"+r,`WhatsApp/${n} ${t} Device/${o}`}},646722:(e,t,n)=>{"use strict";var r=n(595318),o=r(n(145095)),a=n(520289),s=n(257977),c=r(n(904285)),l=n(104617);function i(e){!function(e,t){const n=window.navigator.userAgent;if(n===p&&e.includes("getElementsByTagName"))return;const r=new FormData,i=new Blob([e],{type:"text/plain"});r.append("from_jid",function(){if(f)return f;try{f=JSON.parse((0,o.default)(c.default,"localStorage").getItem(d)),f&&(f=f.replace("-",""))}catch(e){}if(!f){f="unknown"+Math.floor(1e10*Math.random());const e=f;try{(0,o.default)(c.default,"localStorage").setItem(d,JSON.stringify(e))}catch(e){}}return(0,o.default)(f,"id")}()),r.append("agent",(0,s.getLogUserAgent)((0,l.parseUASimple)(n,"2.2224.8"))),r.append("file",i,"logs.txt"),r.append("tags","load");const u=new XMLHttpRequest,_=a.CLB_URL+"?access_token="+encodeURIComponent(a.CLB_TOKEN);u.open("POST",_,!0),u.send(r)}(e)}function u(e){let{error:t,reason:n,stack:r}=e;const o=(new Date).toISOString();return`${o}: error: ${t}\n${o}: reason for logs: ${n}\n${o}: userAgent: ${window.navigator.userAgent}\n${r}`}null==window.onerror&&(window.onerror=function(e,t,n){const r=t.split("?")[0];return"Uncaught SyntaxError: Unexpected token '<'"===e?(function(e){i(u({error:"failed to load a js or css bundle",reason:`failed to load [${e.split("/")[3].replace(/^\//,"")}]`,stack:""}))}(r),!0):(i(u({error:e,reason:`Error at [${r}:${n}]`,stack:""})),!1)});const d="WAUnknownID",p="Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.113 Safari/537.36";let f},104617:(e,t)=>{"use strict";function n(e){return e.includes("windows")?"Windows":e.includes("mac")?"Mac OS":e.includes("linux")?"Linux":"Unparsed"}Object.defineProperty(t,"__esModule",{value:!0}),t.parseUASimple=function(e,t){const r=e.toLowerCase();return{browser:s(r),device:n(r),appVersion:t}};const r=/(chrome|firefox)\/([\w\.]+)/i,o=/(edge|opr)\/([\w\.]+)/i,a={chrome:"Chrome",edge:"Edge",opr:"Opera",firefox:"Firefox"};function s(e){const t=e.match(o)||e.match(r);return null==t?"Unparsed":`${a[t[1]]} ${t[2]}`}},904285:(e,t)=>{"use strict";let n;Object.defineProperty(t,"__esModule",{value:!0}),t.default=void 0;try{n=window.localStorage}catch(e){}var r=n;t.default=r}},e=>{"use strict";e(e.s=646722)}])</script><script defer="defer" src="/vendor1~bootstrap_qr.479b880772705c9f1664.js"></script><script defer="defer" src="/bootstrap_qr.2c01e0e4abde696b6ff5.js"></script><script data-binary-transparency-hash-key="inline-js-9c8cd3d0f4d5af8c7f5cd1c45208edd308bfe472e353a50e4cbacbf6cb58627c">(i => {const l = document.getElementById(i); l &&fetch(l.href).then(b => b.text()).then(code => {const script = document.createElement('script');script.id = 'binary-transparency-manifest';script.type = 'application/json';script.innerHTML = code;document.body.append(script);});} ...
#    "version": "2.2224.8",
#    "hash_function": "SHA256",
#    "root": "0x40a85dec744b8063c38b62968e2c994c51d1d685658d5792603fe89e9502320d",
#    "leaves": [
#      "0x001ccf8cfa2738293a88c9310e932aa1d309ff06fb63d82fd949ec0cbb5a9d6f",
#      "0x00c07573ac9b9b88feb2d38f442d28e77780f9c1fb6d43d6bc8abfb4ce635819",
#      "0x01ffb8bcc8896cdde4ed603cb561521dbaaa4a44493e57c8a9b40607b59146c2",
#      "0x0221a287b686dcbbccb81e234e387daa6a8586ca1f0802ed0a4da7401fd4fed9",
#      "0x041f0886338348bc18bd15bdea0cc4147b91f40980074c70863f71e164bfa75f",
#      "0x0436e2cb1e40471537214c2608f05baa45b906e47b41c5db32b2c44f1206e8bf",
#      "0x04aa37ef95a1e296395bc409312f638a969af8f1df315583320989107172a0e6",
#      "0x067596edefa819f53a771d6f798f9270250f67d7da4f74398ae4ed81e66d5754",
#      "0x07eedfe1774879aef53d8781379fbb6c6804533445cb9b781ca7561ef9e1c080",
#      "0x0873826c294fb3a9c943f0101e9aa53bb8e66b542f9c726868d8af31d2ae4407",
#      "0x093f6844a46c6ddf0696b62637df6df11e507e942cb202b2edce84c19dfed6c3",
#      "0x0a25bc23478c3fd77a473636cc4f818211da694988268537c67374846ef37ce2",
#      "0x0bd4a164d633663750ece14aeddd1988b4e3fd6b11bc8297aa27e44417929845",
#      "0x0c04ec58c1e1b133085f89aaaa05d7176431a9467b36cea39b4a549b7c2d5107",
#      "0x0c4fdce4419591264de09a615e071e6a9275b6ccdcbdfa06322fb8d5ca0fc568",
#      "0x153e10191162e66b01c80f385e207e7214cc52286b991bcdb3b03d870af02b3d",
#      "0x157e52c9bbdccd9a6683b6cc07b9e626af72ce28eba86509ebd655ae5d0d2d40",
#      "0x15ed632752e4b11a05f2c8386552202c087937da7c4979bec8635292101241cb",
#      "0x1ba3c1c310f6465bff685c4807a5bf99ea42ecd8f63c968d1113be0040175b22",
#      "0x1c91241eecdc9a12c7017b1fc5e808e9d3f9a0637b6bd6fa6532b34923a7126f",
#      "0x1c9e8448cb4648e788ca3702c8423a08ed8a85bf10c87ae9e2f9f055e74d0a08",
#      "0x1cc71a48069b464fb5fca1ef47b82d95c9d9603df08fdd334129e8381f571cfb",
#      "0xf4b1133b76ec1dd19c0882fc07d22ccf0a66ec84bf467b29da8187cb6e0ed6f7",
#      "0xf59b5ee8afd04f01ab556fe82bac1644af73d576c2f3c2f12b2342252f840948",
#      "0xf6865ca01e4b6c9eb3853b0cee742e76b9b08704bcc4fd16aca547a7d503e6ef",
#      "0xf7e4cd1333246e1dbc29dcd4ebb3a22a847e70dab314504f4fcf4f96580547cd",
#      "0xf85ff43946f31ed9402e797b492c6038b67b772664bb6f7bbb08a0f82f8e09b2",
#      "0xf873712a2a017d4c47272bfc4b230032e66b66dacf7417e046f548a001513da3",
#      "0xfa5c9e85488e0b9b15a9355605c03691934cdf790debfa28313fab0c8ae2cc65",
#      "0xfc9b6cc57665fde1ce62fab9debdd7b271cc31ba774fec516f32c0e5a1b4f591",
#      "0xfd259690130ddda9ae131b0cb720efec16b924d1846e57f3aa1b5805b02b428d",
#      "0xfd34b401d9ddd9cf4a4e86b760ecb486e24df99576028b03758629341f0fe52b"
#    ]
#  }</script>]

# %% [markdown]
# We see that the soup found all div elements that contain attribute class and value "list-title" but we need the title text only. To extract it, just add .get_text() method to each list element.

# %%
for div_tag in soup.find_all('div',{"class":"list-title"}):
    print(div_tag.get_text())
# Out:
# Keamanan Basis Data Relasional
# Manusia dalam Kemelut Sejarah
# Sejarah Berhala dan Jejak Risalah
# Raja Namrud: Diktator Pertama di Muka Bumi
# Sentuhan Al-Qur`an
# Berjalan Menembus Sepuluh Ribu Hijab
# Yamaha Accoustic Electric Cpx 600
# Russel Ampli Keyboard Multi Kb 70
# Yamaha Acoustic Elektrik Cx-40
# Yamaha Acoustic Electric Apxt2
# Yamaha Accoustic Guitar Junior 2 Nt
# Yamaha Pianica P 32 Dn
# Yamaha Recorder Yrs 20 Pink
# Yamaha Recorder Yrs 20 Biru
# Yamaha Accoustic Gitar Fs 100 C
# Yamaha Accoustic Gitar F 335 Tbs
# Yamaha Accoustic Gitar F 335 Nt
# Yamaha Accoustic Electric Guitar Fsx 315 Cnt
# Yamaha Accoustic Electric Guitar Fsx 315 C Tbs
# Yamaha Accoustic Electric Apx 600

# %% [markdown]
# It is easy, isn't it?
#
# Next, we will do more. Our task is to get information about Title, Author, Price, Link to the book's page, and link refers to image.
#
# Based on the Inspect element, we know that those information locate on:
# - Title: ```<div _ngcontent-web-gramedia-c53="" class="list-title">Creepy Case Club 4: Kasus Pohon Pemanggil</div>```
# - Author: ```<p class="div-author"><span _ngcontent-web-gramedia-c53="" class="list-author ng-star-inserted"> Arvidan None </span>```
# - Price: ```<p _ngcontent-web-gramedia-c53="" class="formats-price">Rp 79.000</p>```
# - Link: ```<div class="ng-star-inserted"><a _ngcontent-web-gramedia-c53="" href="/products/think-and-grow-rich-cara-para-jutawan-dan-miliarder-meraih-kekayaan">```
# - Image: ```<img _ngcontent-web-gramedia-c26="" class="product-list-img ng-star-inserted ng-lazyloaded" src="https://cdn.gramedia.com/uploads/items/9786230405990_Think_and_Grow_Rich__w149_hauto.jpeg" alt="Think And Grow Rich : Cara Para Jutawan Dan Miliarder Meraih Kekayaan">```
#
# Let's we wrap up the code and then input the data into Pandas DataFrame.

# %%
import pandas as pd

data = pd.DataFrame()

data['Title'] = [ title.get_text() for title in soup.find_all( 'div', {"class":"list-title"} ) ]
data['Author'] = [ author.get_text() for author in soup.find_all( 'p', {"class":"div-author"} ) ]
data['Price'] = [ price.get_text() for price in soup.find_all( 'p', {"class":"formats-price"} ) ]
data['Image'] = [ img['src'] for img in soup.find_all( 'img',{"class":"product-list-img"} ) ]

links = []
for tag in soup.find_all( 'div',{"_ngcontent-web-gramedia-c26":"","class":"ng-star-inserted"} ):
    try:
        links.append("https://www.gramedia.com"+tag.find_all('a',{"_ngcontent-web-gramedia-c26":""})[0]['href'])
    except:
        pass

data['Link'] = links

data
# Out:
#                                                 Title  \
# 0                             Tan Malaka: From A To Z
# 1                   What`s The Matter With Insecurity
# 2               What`s The Matter With People Pleaser
# 3          What`s The Matter With Quarter Life Crisis
# 4                               Leave Your Boring Box
# 5                Asyiknya Bikin Sendiri : Kota Baruku
# 6               Asyiknya Bikin Sendiri : Rumah Baruku
# 7                          AKASHA : Fate/Apocrypha 03
# 8                             Yowamushi Pedal, Go! 17
# 9                          Frieren : After the End 02
# 10  Kue Tradisional Indonesia Resep Bakulan Toko K...
# 11                                Misteri Hantu Merah
# 12                              LC: Bakemonogatari 09
# 13                            Wild Police Story-First
# 14                                One Week Friends 04
# 15                        Fujiwara is Almost Right 05
# 16              Kuasa Dalam Doa (The Power In Prayer)
# 17                            Fairy Tail City Hero 01
# 18                                       Blue Lock 04
# 19         Opredo Aktivitas dengan Stiker Pintar: 123
#
#                                                Author      Price  \
# 0                                          Novi Fuji   Rp 34.500
# 1                                     Syamsul Arifin   Rp 53.000
# 2                                  Emirfan T Mulyati   Rp 45.000
# 3                                     Istifatun Zaka   Rp 55.000
# 4                                                      Rp 50.000
# 5                                      Tim Funtastic   Rp 89.000
# 6                                      Tim Funtastic   Rp 89.000
# 7    Akira Ishida  Yuichiro Higashide  Type-Moon N...  Rp 45.000
# 8                                    Wataru Watanabe   Rp 59.000
# 9                       Kanehito Yamada  Tsukasa Abe   Rp 45.000
# 10                           AA Putu Tuti Diantarini   Rp 98.000
# 11                                        Witaru Emi   Rp 55.000
# 12                               NISIOISIN,OH!GREAT    Rp 40.000
# 13                       Aoyama Gosho  Takahiro Arai   Rp 40.000
# 14                                     Matcha Hazuki   Rp 40.000
# 15                                       Nao Hinachi   Rp 40.000
# 16                                  Charles Spurgeon   Rp 52.000
# 17                                      Hiro Mashima   Rp 40.000
# 18                 Muneyuki Kaneshiro  Yusuke Nomura   Rp 45.000
# 19                                   Veronica Winata   Rp 70.000
#
#                                                 Image  \
# 0   https://cdn.gramedia.com/uploads/items/Tan_Mal...
# 1   https://cdn.gramedia.com/uploads/items/Whats_T...
# 2   https://cdn.gramedia.com/uploads/items/Whats_T...
# 3   https://cdn.gramedia.com/uploads/items/Whats_T...
# 4   https://cdn.gramedia.com/uploads/items/Leave_Y...
# 5   https://cdn.gramedia.com/uploads/items/COV_kot...
# 6                  /assets/default-images/product.png
# 7                  /assets/default-images/product.png
# 8                  /assets/default-images/product.png
# 9                  /assets/default-images/product.png
# 10                 /assets/default-images/product.png
# 11                 /assets/default-images/product.png
# 12                 /assets/default-images/product.png
# 13                 /assets/default-images/product.png
# 14                 /assets/default-images/product.png
# 15                 /assets/default-images/product.png
# 16                 /assets/default-images/product.png
# 17                 /assets/default-images/product.png
# 18                 /assets/default-images/product.png
# 19                 /assets/default-images/product.png
#
#                                                  Link
# 0   https://www.gramedia.com/products/tan-malaka-f...
# 1   https://www.gramedia.com/products/whats-the-ma...
# 2   https://www.gramedia.com/products/whats-the-ma...
# 3   https://www.gramedia.com/products/whats-the-ma...
# 4   https://www.gramedia.com/products/leave-your-b...
# 5   https://www.gramedia.com/products/asyiknya-bik...
# 6   https://www.gramedia.com/products/asyiknya-bik...
# 7   https://www.gramedia.com/products/akasha-fatea...
# 8   https://www.gramedia.com/products/yowamushi-pe...
# 9   https://www.gramedia.com/products/frieren-afte...
# 10  https://www.gramedia.com/products/kue-tradisio...
# 11  https://www.gramedia.com/products/misteri-hant...
# 12  https://www.gramedia.com/products/lc-bakemonog...
# 13  https://www.gramedia.com/products/wild-police-...
# 14  https://www.gramedia.com/products/one-week-fri...
# 15  https://www.gramedia.com/products/fujiwara-is-...
# 16  https://www.gramedia.com/products/kuasa-dalam-...
# 17  https://www.gramedia.com/products/fairy-tail-c...
# 18     https://www.gramedia.com/products/blue-lock-04
# 19  https://www.gramedia.com/products/opredo-aktiv...

# %% [markdown]
# ## Multipage

# %% [markdown]
# Currently, we are working on a page. However, the rest of the web consist of more pages like below:
#
# <img src="https://i.ibb.co/CQ6JQLv/message-Image-1636716930335.jpg"></img>
#
# If we look at the next page such as page 2, we can see that the url change to https://www.gramedia.com/categories/buku?page=2 and page 3: https://www.gramedia.com/categories/buku?page=3. Then we know each page has a numbering format on url so we can access many pages one time automatically using loop. We exclude the image since image loader is very depended on your connection. Let's check the code below.

# %%
title = []
author = []
price = []
image = []
Links = []

driver = webdriver.Chrome('Web Scraping/chromedriver')

for i in range(1,21):
    url="https://www.gramedia.com/categories/buku?page={}".format(i)
    driver.get(url)
    html = driver.page_source
    soup = BeautifulSoup(html, "html.parser")

    title += [ title.get_text() for title in soup.find_all( 'div', {"class":"list-title"} ) ]
    author += [ author.get_text() for author in soup.find_all( 'p', {"class":"div-author"} ) ]
    price += [ price.get_text() for price in soup.find_all( 'p', {"class":"formats-price"} ) ]
    image += [ img['src'] for img in soup.find_all( 'img',{"class":"product-list-img"} ) ]

    links = []
    for tag in soup.find_all( 'div',{"_ngcontent-web-gramedia-c26":"","class":"ng-star-inserted"} ):
        try:
            links.append("https://www.gramedia.com"+tag.find_all('a',{"_ngcontent-web-gramedia-c26":""})[0]['href'])
        except:
            pass
    Links += links

data_multipage = pd.DataFrame()
data_multipage['Title'] = title
data_multipage['Author'] = author
data_multipage['Price'] = price
data_multipage['Image'] = image
data_multipage['Link'] = Links

data_multipage
# Out:
# C:\Users\wahyu\AppData\Local\Temp\ipykernel_11896\2364669648.py:7: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('Web Scraping/chromedriver')
#                                                  Title  \
# 0                       Keamanan Basis Data Relasional
# 1                        Manusia dalam Kemelut Sejarah
# 2                    Sejarah Berhala dan Jejak Risalah
# 3           Raja Namrud: Diktator Pertama di Muka Bumi
# 4                                   Sentuhan Al-Qur`an
# ..                                                 ...
# 375  Buku Referensi  Program  Keluarga  Berencana  ...
# 376  Hukum Keperawatan (Sebuah Paradigma Kebebasan ...
# 377  Anatomi dan Fisiologi untuk Mahasiswa Keperawatan
# 378              Disleksia - Perkembangan Di Indonesia
# 379                Buku Ajar Panduan Lengkap Imunisasi
#
#                                                 Author      Price  \
# 0                         SUWANTO RAHARJO & EMA UTAMI   Rp 67.150
# 1     Taufik Abdullah, Aswab Mahasin, Daniel Dhakidae   Rp 59.500
# 2                               Wisnu Tanggap Prabowo   Rp 72.250
# 3                                 Manshur Abdul Hakim   Rp 55.250
# 4                                      Adham Syarqawi   Rp 76.500
# ..                                                 ...        ...
# 375   DR. Ai Yeyeh Rukiyah,  S.SiT. dkk  Dr. Ai Yey...  Rp 59.000
# 376   Aris Prio Agus Santoso, A.Md.Kep, SH., MH.Kes...  Rp 89.000
# 377                       Ns. Tarwoto, S.Kep  Tarwoto   Rp 89.000
# 378                         Harwintha Y. Anjarningsih   Rp 45.000
# 379   MARLIANA RAHMA  Marliana Rahma, SST., M.Keb.,...  Rp 45.000
#
#                                                  Image  \
# 0    https://cdn.gramedia.com/uploads/items/Keamana...
# 1    https://cdn.gramedia.com/uploads/items/MANUSIA...
# 2    https://cdn.gramedia.com/uploads/items/Sejarah...
# 3    https://cdn.gramedia.com/uploads/items/Raja_Na...
# 4    https://cdn.gramedia.com/uploads/items/Sentuha...
# ..                                                 ...
# 375                 /assets/default-images/product.png
# 376                 /assets/default-images/product.png
# 377                 /assets/default-images/product.png
# 378                 /assets/default-images/product.png
# 379                 /assets/default-images/product.png
#
#                                                   Link
# 0    https://www.gramedia.com/products/keamanan-bas...
# 1    https://www.gramedia.com/products/manusia-dala...
# 2    https://www.gramedia.com/products/sejarah-berh...
# 3    https://www.gramedia.com/products/raja-namrud-...
# 4    https://www.gramedia.com/products/sentuhan-al-...
# ..                                                 ...
# 375  https://www.gramedia.com/products/buku-referen...
# 376  https://www.gramedia.com/products/hukum-kepera...
# 377  https://www.gramedia.com/products/anatomi-dan-...
# 378  https://www.gramedia.com/products/disleksia-pe...
# 379  https://www.gramedia.com/products/buku-ajar-pa...
#
# [380 rows x 5 columns]

# %% [markdown]
# ## Accessing Individual Page
#
# <img src="https://i.ibb.co/F8D5bCy/message-Image-1637134633305.jpg"></img>
#
# Suppose that we want to get more detail information about the books, but the information are on the individual page. So, we will access the individual page and scrape some information on it. We will catch title, author, price, description, number of pages, date of issue and publisher.

# %%
title = []
author = []
price = []
desc = []
num_pages = []
date_issue = []
publisher = []

driver = webdriver.Chrome('Web Scraping/chromedriver')

for i in range(1,3):
    url="https://www.gramedia.com/categories/buku?page={}".format(i)
    driver.get(url)
    html = driver.page_source
    soup = BeautifulSoup(html, "html.parser")

    for tag in soup.find_all( 'div',{"_ngcontent-web-gramedia-c26":"","class":"ng-star-inserted"} ):
        try:
            link = "https://www.gramedia.com"+tag.find('a',{"_ngcontent-web-gramedia-c26":""})['href']
            driver.get(link)
            html_ind = driver.page_source
            soup_ind = BeautifulSoup(html_ind, "html.parser")

            title.append( soup_ind.find( 'div', {"class":"book-title"} ).get_text() )
            author.append( soup_ind.find('span',{"class":"title-author"}).get_text() )
            price.append( soup_ind.find('div', {'class':'price-product'}).get_text() )
            desc.append( soup_ind.find('pre').get_text() )
            num_pages.append( soup_ind.find('div',{'class':'detail-section'}).find_all('p')[0].get_text() )
            date_issue.append( soup_ind.find('div',{'class':'detail-section'}).find_all('p')[2].get_text() )
            publisher.append( soup_ind.find('div',{'class':'detail-section'}).find_all('p')[1].get_text() )

        except:
            pass

pages = pd.DataFrame()
pages['Title'] = title
pages['Author'] = author
pages['Price'] = price
pages['Desc'] = desc
pages['Num Pages'] = num_pages
pages['Date Issue'] = date_issue
pages['Publisher'] = publisher

pages
# Out:
# C:\Users\wahyu\AppData\Local\Temp\ipykernel_11896\1562797886.py:9: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('Web Scraping/chromedriver')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\wahyu\data_science\learning_journal\phase_0\week_3\d5pm WEB scraping.ipynb Cell 22' in <cell line: 37>()
#      <a href='vscode-notebook-cell:/c%3A/Users/wahyu/data_science/learning_journal/phase_0/week_3/d5pm%20WEB%20scraping.ipynb#ch0000021?line=34'>35</a> pages = pd.DataFrame()
#      <a href='vscode-notebook-cell:/c%3A/Users/wahyu/data_science/learning_journal/phase_0/week_3/d5pm%20WEB%20scraping.ipynb#ch0000021?line=35'>36</a> pages['Title'] = title
# ---> <a href='vscode-notebook-cell:/c%3A/Users/wahyu/data_science/learning_journal/phase_0/week_3/d5pm%20WEB%20scraping.ipynb#ch0000021?line=36'>37</a> pages['Author'] = author
#      <a href='vscode-notebook-cell:/c%3A/Users/wahyu/data_science/learning_journal/phase_0/week_3/d5pm%20WEB%20scraping.ipynb#ch0000021?line=37'>38</a> pages['Price'] = price
#      <a href='vscode-notebook-cell:/c%3A/Users/wahyu/data_science/learning_journal/phase_0/week_3/d5pm%20WEB%20scraping.ipynb#ch0000021?line=38'>39</a> pages['Desc'] = desc
#
# File c:\Users\wahyu\anaconda3\lib\site-packages\pandas\core\frame.py:3655, in DataFrame.__setitem__(self, key, value)
#    <a href='file:///c%3A/Users/wahyu/anaconda3/lib/site-packages/pandas/core/frame.py?line=3651'>3652</a>     self._setitem_array([key], value)
#    <a href='file:///c%3A/Users/wahyu/anaconda3/lib/site-packages/pandas/core/frame.py?line=3652'>3653</a> else:
#    <a href='file:///c%3A/Users/wahyu/anaconda3/lib/site-packages/pandas/core/frame.py?line=3653'>3654</a>     # set column
# -> <a href='file:///c%3A/Users/wahyu/anaconda3/lib/site-packages/pandas/core/frame.py?line=3654'>3655</a>     self._set_item(key, value)
#
# File c:\Users\wahyu\anaconda3\lib\site-packages\pandas\core\frame.py:3832, in DataFrame._set_item(self, key, value)
#    <a href='file:///c%3A/Users/wahyu/anaconda3/lib/site-packages/pandas/core/frame.py?line=3821'>3822</a> def _set_item(self, key, value) -> None:
#    <a href='file:///c%3A/Users/wahyu/anaconda3/lib/site-packages/pandas/core/frame.py?line=3822'>3823</a>     """
#    <a href='file:///c%3A/Users/wahyu/anaconda3/lib/site-packages/pandas/core/frame.py?line=3823'>3824</a>     Add series to DataFrame in specified column.
#    <a href='file:///c%3A/Users/wahyu/anaconda3/lib/site-packages/pandas/core/frame.py?line=3824'>3825</a>
#    (...)
#    <a href='file:///c%3A/Users/wahyu/anaconda3/lib/site-packages/pandas/core/frame.py?line=3829'>3830</a>     ensure homogeneity.
#    <a href='file:///c%3A/Users/wahyu/anaconda3/lib/site-packages/pandas/core/frame.py?line=3830'>3831</a>     """
# -> <a href='file:///c%3A/Users/wahyu/anaconda3/lib/site-packages/pandas/core/frame.py?line=3831'>3832</a>     value = self._sanitize_column(value)
#    <a href='file:///c%3A/Users/wahyu/anaconda3/lib/site-packages/pandas/core/frame.py?line=3833'>3834</a>     if (
#    <a href='file:///c%3A/Users/wahyu/anaconda3/lib/site-packages/pandas/core/frame.py?line=3834'>3835</a>         key in self.columns
#    <a href='file:///c%3A/Users/wahyu/anaconda3/lib/site-packages/pandas/core/frame.py?line=3835'>3836</a>         and value.ndim == 1
#    <a href='file:///c%3A/Users/wahyu/anaconda3/lib/site-packages/pandas/core/frame.py?line=3836'>3837</a>         and not is_extension_array_dtype(value)
#    <a href='file:///c%3A/Users/wahyu/anaconda3/lib/site-packages/pandas/core/frame.py?line=3837'>3838</a>     ):
#    <a href='file:///c%3A/Users/wahyu/anaconda3/lib/site-packages/pandas/core/frame.py?line=3838'>3839</a>         # broadcast across multiple columns if necessary
#    <a href='file:///c%3A/Users/wahyu/anaconda3/lib/site-packages/pandas/core/frame.py?line=3839'>3840</a>         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File c:\Users\wahyu\anaconda3\lib\site-packages\pandas\core\frame.py:4535, in DataFrame._sanitize_column(self, value)
#    <a href='file:///c%3A/Users/wahyu/anaconda3/lib/site-packages/pandas/core/frame.py?line=4531'>4532</a>     return _reindex_for_setitem(value, self.index)
#    <a href='file:///c%3A/Users/wahyu/anaconda3/lib/site-packages/pandas/core/frame.py?line=4533'>4534</a> if is_list_like(value):
# -> <a href='file:///c%3A/Users/wahyu/anaconda3/lib/site-packages/pandas/core/frame.py?line=4534'>4535</a>     com.require_length_match(value, self.index)
#    <a href='file:///c%3A/Users/wahyu/anaconda3/lib/site-packages/pandas/core/frame.py?line=4535'>4536</a> return sanitize_array(value, self.index, copy=True, allow_2d=True)
#
# File c:\Users\wahyu\anaconda3\lib\site-packages\pandas\core\common.py:557, in require_length_match(data, index)
#     <a href='file:///c%3A/Users/wahyu/anaconda3/lib/site-packages/pandas/core/common.py?line=552'>553</a> """
#     <a href='file:///c%3A/Users/wahyu/anaconda3/lib/site-packages/pandas/core/common.py?line=553'>554</a> Check the length of data matches the length of the index.
#     <a href='file:///c%3A/Users/wahyu/anaconda3/lib/site-packages/pandas/core/common.py?line=554'>555</a> """
#     <a href='file:///c%3A/Users/wahyu/anaconda3/lib/site-packages/pandas/core/common.py?line=555'>556</a> if len(data) != len(index):
# --> <a href='file:///c%3A/Users/wahyu/anaconda3/lib/site-packages/pandas/core/common.py?line=556'>557</a>     raise ValueError(
#     <a href='file:///c%3A/Users/wahyu/anaconda3/lib/site-packages/pandas/core/common.py?line=557'>558</a>         "Length of values "
#     <a href='file:///c%3A/Users/wahyu/anaconda3/lib/site-packages/pandas/core/common.py?line=558'>559</a>         f"({len(data)}) "
#     <a href='file:///c%3A/Users/wahyu/anaconda3/lib/site-packages/pandas/core/common.py?line=559'>560</a>         "does not match length of index "
#     <a href='file:///c%3A/Users/wahyu/anaconda3/lib/site-packages/pandas/core/common.py?line=560'>561</a>         f"({len(index)})"
#     <a href='file:///c%3A/Users/wahyu/anaconda3/lib/site-packages/pandas/core/common.py?line=561'>562</a>     )
#
# ValueError: Length of values (14) does not match length of index (20)

# %%
from bs4 import BeautifulSoup
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel 'base (Python 3.9.12)' due to connection timeout.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import pandas as pd
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel 'base (Python 3.9.12)' due to connection timeout.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
respons=requests.get('https://news.ycombinator.com/').text
soup=BeautifulSoup(respons, 'lxml')
#title=soup.find_all('a',class='score')
#data1=pd.DataFrame()
#data2=pd.DataFrame()
#data3=pd.DataFrame()
#title=soup.find_all('a', class='titlelink').text
data1['title']=[title.text for title in soup.find_all('a',class_='titlelink')]
